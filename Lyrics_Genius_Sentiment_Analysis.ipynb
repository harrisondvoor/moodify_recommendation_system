# %%
# !pip install textblob
# !pip install lyricsgenius

# %%
from textblob import TextBlob

# %%
import lyricsgenius

# %%
import pandas as pd

# %%
# Get the lyricsgenius using the genius access token
genius = lyricsgenius.Genius('W6oSGZZooTCvJWWiMl207wnwXFIaIEDYeoxDEhDfNhOYxz0l4HSFlzPum03PfBEV')

# %%
# Load the dataset
df = pd.read_csv('/Users/hdvoor/Desktop/spotify_top_2023.csv', encoding='latin-1')

# %%
# Preview the dataset
df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
# Filter rows where artist_count is equal to 1
df = df[df['artist_count'] == 1]

# %%
# Drop rows with non-ASCII characters instead of replacing the values
df = df[df['artist(s)_name'].apply(lambda x: all(ord(c) < 128 for c in x))]
df = df[df['track_name'].apply(lambda x: all(ord(c) < 128 for c in x))]

# %%
# Function to fetch lyrics from Genius API
def get_lyrics(row):
    try:
        # Search for the lyrics using the artist and song title
        song = genius.search_song(row['track_name'], row['artist(s)_name'])
        # Return the lyrics if found
        return song.lyrics if song else None
    except Exception as e:
        print(f"Error fetching lyrics for {row['artist(s)_name']} - {row['track_name']}: {e}")
        return None

# %%
# Apply the function to fetch lyrics and create a new 'lyrics' column
df['lyrics'] = df.apply(get_lyrics, axis=1)
# Out:
# Searching for "LALA" by Myke Towers...
# Done.
# Searching for "vampire" by Olivia Rodrigo...
# Done.
# Searching for "Cruel Summer" by Taylor Swift...
# Done.
# Searching for "WHERE SHE GOES" by Bad Bunny...
# Done.
# Searching for "Columbia" by Quevedo...
# Done.
# Searching for "fukumean" by Gunna...
# Done.
# Searching for "Super Shy" by NewJeans...
# Done.
# Searching for "Flowers" by Miley Cyrus...
# Done.
# Searching for "Daylight" by David Kushner...
# Done.
# Searching for "As It Was" by Harry Styles...
# Done.
# Searching for "Kill Bill" by SZA...
# Done.
# Searching for "Cupid - Twin Ver." by Fifty Fifty...
# Done.
# Searching for "What Was I Made For? [From The Motion Picture "Barbie"]" by Billie Eilish...
# Done.
# Searching for "Like Crazy" by Jimin...
# Done.
# Searching for "I Wanna Be Yours" by Arctic Monkeys...
# Done.
# Searching for "SABOR FRESA" by Fuerza Regida...
# Done.
# Searching for "Last Night" by Morgan Wallen...
# Done.
# ...

# %%
# Drop rows where lyrics couldn't be fetched
df = df.dropna(subset=['lyrics'])

# %%
# Function to get mood categories based on lyrics sentiment
def get_mood(text):
    analysis = TextBlob(text)
    if analysis.sentiment.polarity > 0.4:
        return 'Ecstatic'
    elif 0.2 < analysis.sentiment.polarity <= 0.4:
        return 'Happy'
    elif 0 <= analysis.sentiment.polarity <= 0.2:
        return 'Okay'
    elif -0.2 <= analysis.sentiment.polarity < 0:
        return 'Sad'
    else:
        return 'Bummed'

# %%
# Apply the mood analysis function to the 'lyrics' column and create a new 'mood' column
df['mood'] = df['lyrics'].apply(get_mood)

# %%
# Drop column (because we don't need lyrics column)
df = df.drop(columns=['lyrics'])

# %%
from sqlalchemy import create_engine, text

# %%
# Pass the connection string to a variable, conn_url
conn_url = 'postgresql://postgres:123@localhost/SPOTIFY_MOOD_FINAL'

# %%
# Create an engine that connects to PostgreSQL server
engine = create_engine(conn_url)

# %%
# Establish a connection
connection = engine.connect()

# %%
# Pass the SQL statements that create all tables
stmt = text("""
    CREATE TABLE spotify (
        song_id INT PRIMARY KEY,
        song_name VARCHAR(100),
        artist VARCHAR(100),
        artist_count INT,
        released_year INT,  
        released_month INT,
        released_day INT,
        in_spotify_playlists INT,
        in_spotify_charts INT,
        streams BIGINT,
        bpm INT,
        key CHAR(2),
        mode VARCHAR(10),
        danceability INT,
        valence INT,
        energy INT,
        acousticness INT,
        instrumentalness INT,
        liveness INT,
        speechiness INT,
        mood VARCHAR(50)
    );
""")

# %%
# Execute the statement to create tables
connection.execute(stmt)

# %%
spotify = df.rename(columns={'track_name': 'song_name', 'artist(s)_name': 'artist','danceability_%':'danceability', 'valence_%':'valence', 'energy_%':'energy', 'acousticness_%':'acousticness','instrumentalness_%':'instrumentalness','liveness_%':'liveness','speechiness_%':'speechiness'})

# %%
spotify.head()
# Out:
#         song_name          artist  artist_count  released_year  \
# 1            LALA     Myke Towers             1           2023
# 2         vampire  Olivia Rodrigo             1           2023
# 3    Cruel Summer    Taylor Swift             1           2019
# 4  WHERE SHE GOES       Bad Bunny             1           2023
# 7        Columbia         Quevedo             1           2023
#
#    released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 1               3            23                  1474                 48
# 2               6            30                  1397                113
# 3               8            23                  7858                100
# 4               5            18                  3133                 50
# 7               7             7                   714                 43
#
#      streams  in_apple_playlists  ...  key   mode  danceability valence  \
# ...

# %%
# Drop na from spotify
spotify = spotify.dropna(subset=['song_name']).copy()

# %%
# Insert 'song_id' column
spotify.insert(0,'song_id',range(1,1 + len(spotify)))

# %%
spotify = spotify[['song_id','song_name','artist','artist_count','released_year','released_month','released_day','in_spotify_playlists','in_spotify_charts','streams','bpm','key','mode','danceability','valence','energy','acousticness','instrumentalness','liveness','speechiness','mood']]

# %%
spotify = spotify[spotify['streams'] != 'BPM110KeyAModeMajorDanceability53Valence75Energy69Acousticness7Instrumentalness0Liveness17Speechiness3']

# %%
# Add spotify df to SQL database
spotify.to_sql('spotify', con = engine, if_exists = 'append', index = False)
# Out:
# 533

# %%
spotify
# Out:
#      song_id                  song_name          artist  artist_count  \
# 1          1                       LALA     Myke Towers             1
# 2          2                    vampire  Olivia Rodrigo             1
# 3          3               Cruel Summer    Taylor Swift             1
# 4          4             WHERE SHE GOES       Bad Bunny             1
# 7          5                   Columbia         Quevedo             1
# ..       ...                        ...             ...           ...
# 945      530            BackOutsideBoyz           Drake             1
# 947      531              The Great War    Taylor Swift             1
# 948      532               My Mind & Me    Selena Gomez             1
# 949      533  Bigger Than The Whole Sky    Taylor Swift             1
# 952      534                      Alone       Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# ...

# %%
#for internal reference and validation
spotify.to_csv('input_for_spotify_api.csv',index=False)
